# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
    
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

input_file = ''
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        input_file = os.path.join(dirname, filename)
        print(input_file)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/student-grade-prediction/student-mat.csv

# %% [markdown]
# ## Important Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# moore libraries
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset


import sklearn
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Import Data

# %%
data = pd.read_csv(input_file)

data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data.info()
data.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
#  19  nursery     395 non-null    object
#  20  higher      395 non-null    object
#  21  internet    395 non-null    object
#  22  romantic    395 non-null    object
#  23  famrel      395 non-null    int64
#  24  freetime    395 non-null    int64
#  25  goout       395 non-null    int64
#  26  Dalc        395 non-null    int64
#  27  Walc        395 non-null    int64
#  28  health      395 non-null    int64
#  29  absences    395 non-null    int64
#  30  G1          395 non-null    int64
#  31  G2          395 non-null    int64
#  32  G3          395 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 102.0+ KB
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# ## Preprocessing data
#
# ### step 1: encoding non-numeric values

# %%
non_numeric_columns = ['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 
                       'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
                       'nursery', 'higher', 'internet', 'romantic']

# One-Hot Encoding
data_one_hot = pd.get_dummies(data, columns=non_numeric_columns)

# Label Encoding
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data_label_encoded = data.copy()
for column in non_numeric_columns:
    data_label_encoded[column] = label_encoder.fit_transform(data_label_encoded[column])

# Display the encoded data
print("One-Hot Encoded Data:")
print(data_one_hot.head())

print("\nLabel Encoded Data:")
print(data_label_encoded.head())
# Out:
# One-Hot Encoded Data:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  ...  activities_no  activities_yes  nursery_no  nursery_yes  \
# 0     1  ...           True           False       False         True
# 1     1  ...           True           False        True        False
# 2     2  ...           True           False       False         True
# 3     1  ...          False            True       False         True
# 4     1  ...           True           False       False         True
#
#    higher_no  higher_yes  internet_no  internet_yes  romantic_no  romantic_yes
# 0      False        True         True         False         True         False
# 1      False        True        False          True         True         False
# 2      False        True        False          True         True         False
# 3      False        True        False          True        False          True
# 4      False        True         True         False         True         False
#
# [5 rows x 59 columns]
#
# Label Encoded Data:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       0    0   18        1        0        0     4     4     0     4  ...
# 1       0    0   17        1        0        1     1     1     0     2  ...
# 2       0    0   15        1        1        1     1     1     0     2  ...
# 3       0    0   15        1        0        1     4     2     1     3  ...
# 4       0    0   16        1        0        1     3     3     2     2  ...
#
#    famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0       4         3      4     1     1       3         6   5   6   6
# 1       5         3      3     1     1       3         4   5   5   6
# 2       4         3      2     2     3       3        10   7   8  10
# 3       3         2      2     1     1       5         2  15  14  15
# 4       4         3      2     1     2       5         4   6  10  10
#
# [5 rows x 33 columns]

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
data_one_hot
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0     18     4     4           2          2         0       4         3
# 1     17     1     1           1          2         0       5         3
# 2     15     1     1           1          2         3       4         3
# 3     15     4     2           1          3         0       3         2
# 4     16     3     3           1          2         0       4         3
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 390   20     2     2           1          2         2       5         5
# 391   17     3     1           2          1         0       2         4
# 392   21     1     1           1          1         3       5         5
# 393   18     3     2           3          1         0       4         4
# 394   19     1     1           1          1         0       3         2
#
#      goout  Dalc  ...  activities_no  activities_yes  nursery_no  nursery_yes  \
# 0        4     1  ...           True           False       False         True
# 1        3     1  ...           True           False        True        False
# 2        2     2  ...           True           False       False         True
# 3        2     1  ...          False            True       False         True
# 4        2     1  ...           True           False       False         True
# ..     ...   ...  ...            ...             ...         ...          ...
# 390      4     4  ...           True           False       False         True
# 391      5     3  ...           True           False        True        False
# 392      3     3  ...           True           False        True        False
# 393      1     3  ...           True           False        True        False
# 394      3     3  ...           True           False       False         True
#
#      higher_no  higher_yes  internet_no  internet_yes  romantic_no  \
# 0        False        True         True         False         True
# 1        False        True        False          True         True
# 2        False        True        False          True         True
# 3        False        True        False          True        False
# 4        False        True         True         False         True
# ..         ...         ...          ...           ...          ...
# 390      False        True         True         False         True
# 391      False        True        False          True         True
# 392      False        True         True         False         True
# 393      False        True        False          True         True
# 394      False        True        False          True         True
#
#      romantic_yes
# 0           False
# 1           False
# 2           False
# 3            True
# 4           False
# ..            ...
# 390         False
# 391         False
# 392         False
# 393         False
# 394         False
#
# [395 rows x 59 columns]

# %%
data_label_encoded
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        1        0        0     4     4     0     4  ...
# 1         0    0   17        1        0        1     1     1     0     2  ...
# 2         0    0   15        1        1        1     1     1     0     2  ...
# 3         0    0   15        1        0        1     4     2     1     3  ...
# 4         0    0   16        1        0        1     3     3     2     2  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       1    1   20        1        1        0     2     2     3     3  ...
# 391       1    1   17        1        1        1     3     1     3     3  ...
# 392       1    1   21        0        0        1     1     1     2     2  ...
# 393       1    1   18        0        1        1     3     2     3     2  ...
# 394       1    1   19        1        1        1     1     1     2     0  ...
#
#      famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0         4         3      4     1     1       3         6   5   6   6
# 1         5         3      3     1     1       3         4   5   5   6
# 2         4         3      2     2     3       3        10   7   8  10
# 3         3         2      2     1     1       5         2  15  14  15
# 4         4         3      2     1     2       5         4   6  10  10
# ..      ...       ...    ...   ...   ...     ...       ...  ..  ..  ..
# 390       5         5      4     4     5       4        11   9   9   9
# 391       2         4      5     3     4       2         3  14  16  16
# 392       5         5      3     3     3       3         3  10   8   7
# 393       4         4      1     3     4       5         0  11  12  10
# 394       3         2      3     3     3       5         5   8   9   9
#
# [395 rows x 33 columns]

# %%
data = data_label_encoded

# %% [markdown]
# ### Split Data into X and y features
#
# `X` will be a matrix of features while `y` will be a column vector of target attribute `G3`

# %%
y = data['G3'].copy()
X = data.drop('G3', axis=1).copy()
y
# Out:
# 0       6
# 1       6
# 2      10
# 3      15
# 4      10
#        ..
# 390     9
# 391    16
# 392     7
# 393    10
# 394     9
# Name: G3, Length: 395, dtype: int64

# %% [markdown]
# ## Visualizing data
#
# ### Visualize correlation of features with final grade(g3)

# %% [markdown]
# ### Use Scatter plot of individual features

# %%
correlations = data.drop(columns=['G3']).corrwith(data['G3'])
correlations
# Out:
# school       -0.045017
# sex           0.103456
# age          -0.161579
# address       0.105756
# famsize       0.081407
# Pstatus      -0.058009
# Medu          0.217147
# Fedu          0.152457
# Mjob          0.102082
# Fjob          0.042286
# reason        0.121994
# guardian     -0.070109
# traveltime   -0.117142
# studytime     0.097820
# failures     -0.360415
# schoolsup    -0.082788
# famsup       -0.039157
# paid          0.101996
# activities    0.016100
# nursery       0.051568
# higher        0.182465
# internet      0.098483
# romantic     -0.129970
# famrel        0.051363
# freetime      0.011307
# goout        -0.132791
# Dalc         -0.054660
# Walc         -0.051939
# health       -0.061335
# absences      0.034247
# G1            0.801468
# G2            0.904868
# dtype: float64

# %%
# Select top 6 features with highest correlation with G3
# G3 is excluded from the correlation calculation
correlations = data.drop(columns=['G3']).corrwith(data['G3'])

# Select top-k features (excluding G3) with highest absolute correlation coefficients
top_k_features = correlations.abs().nlargest(15)
bottom_K = correlations.abs().nsmallest(15)
#print(top_k_features)
print(bottom_K)
# Out:
# freetime      0.011307
# activities    0.016100
# absences      0.034247
# famsup        0.039157
# Fjob          0.042286
# school        0.045017
# famrel        0.051363
# nursery       0.051568
# Walc          0.051939
# Dalc          0.054660
# Pstatus       0.058009
# health        0.061335
# guardian      0.070109
# famsize       0.081407
# schoolsup     0.082788
# dtype: float64

# %%
# plot the scatter plot graphs now

plt.figure(figsize=(12, 18))



# First subplot for feature1
plt.subplot(3, 2, 1)  # 3 rows, 2 columns, subplot index 1
plt.scatter(x=data['G2'], y=data['G3'], color='skyblue')
plt.title('G2')
plt.xlabel('G2')
plt.ylabel('G3')

# Second subplot for feature2
plt.subplot(3, 2, 2)  # 3 rows, 2 columns, subplot index 2
plt.scatter(x=data['G1'], y=data['G3'], color='skyblue')
plt.title('G1')
plt.xlabel('G1')
plt.ylabel('G3')

# Third subplot for feature3
plt.subplot(3, 2, 3)  # 3 rows, 2 columns, subplot index 3
plt.scatter(x=data['failures'], y=data['G3'], color='skyblue')
plt.title('failures')
plt.xlabel('failures')
plt.ylabel('G3')

# Fourth subplot for feature4
plt.subplot(3, 2, 4)  # 3 rows, 2 columns, subplot index 4
plt.scatter(x=data['Medu'], y=data['G3'], color='skyblue')
plt.title('Medu')
plt.xlabel('Medu')
plt.ylabel('G3')

# Fifth subplot for feature5
plt.subplot(3, 2, 5)  # 3 rows, 2 columns, subplot index 5
plt.scatter(x=data['higher'], y=data['G3'], color='skyblue')
plt.title('higher')
plt.xlabel('higher')
plt.ylabel('G3')

# Sixth subplot for feature6
plt.subplot(3, 2, 6)  # 3 rows, 2 columns, subplot index 6
plt.scatter(x=data['age'], y=data['G3'], color='skyblue')
plt.title('age')
plt.xlabel('age')
plt.ylabel('G3')

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %% [markdown]
# ## Drop some more columns
#
# Let's see the columns with the lowest correlation:

# %%
correlations = data.drop(columns=['G3']).corrwith(data['G3'])

# Select bottom-k features (excluding G3) with lowest absolute correlation coefficients
top_k_features = correlations.abs().nlargest(15)
bottom_K = correlations.abs().nsmallest(15)

print(bottom_K)
# Out:
# freetime      0.011307
# activities    0.016100
# absences      0.034247
# famsup        0.039157
# Fjob          0.042286
# school        0.045017
# famrel        0.051363
# nursery       0.051568
# Walc          0.051939
# Dalc          0.054660
# Pstatus       0.058009
# health        0.061335
# guardian      0.070109
# famsize       0.081407
# schoolsup     0.082788
# dtype: float64

# %%
new_data = data.drop(columns=['freetime', 'activities', 'absences', 'famsup', 'Fjob', 'school', 'famrel', 'nursery',
                             'Walc', 'Dalc', 'Pstatus', 'health', 'guardian', 'famsize', 'schoolsup'
  
                            ]).copy()

new_data.to_csv('data_before_scaling.csv', index=False)
new_data
# Out:
#      sex  age  address  Medu  Fedu  Mjob  reason  traveltime  studytime  \
# 0      0   18        1     4     4     0       0           2          2
# 1      0   17        1     1     1     0       0           1          2
# 2      0   15        1     1     1     0       2           1          2
# 3      0   15        1     4     2     1       1           1          3
# 4      0   16        1     3     3     2       1           1          2
# ..   ...  ...      ...   ...   ...   ...     ...         ...        ...
# 390    1   20        1     2     2     3       0           1          2
# 391    1   17        1     3     1     3       0           2          1
# 392    1   21        0     1     1     2       0           1          1
# 393    1   18        0     3     2     3       0           3          1
# 394    1   19        1     1     1     2       0           1          1
#
#      failures  paid  higher  internet  romantic  goout  G1  G2  G3
# 0           0     0       1         0         0      4   5   6   6
# 1           0     0       1         1         0      3   5   5   6
# 2           3     1       1         1         0      2   7   8  10
# 3           0     1       1         1         1      2  15  14  15
# 4           0     1       1         0         0      2   6  10  10
# ..        ...   ...     ...       ...       ...    ...  ..  ..  ..
# 390         2     1       1         0         0      4   9   9   9
# 391         0     0       1         1         0      5  14  16  16
# 392         3     0       1         0         0      3  10   8   7
# 393         0     0       1         1         0      1  11  12  10
# 394         0     0       1         1         0      3   8   9   9
#
# [395 rows x 18 columns]

# %% [markdown]
# ## Split Data into X and y features, and then scale it.
#
# ### Split data to `X` and `y`

# %%
y = new_data['G3'].copy()
X = new_data.drop('G3', axis=1).copy()
X
# Out:
#      sex  age  address  Medu  Fedu  Mjob  reason  traveltime  studytime  \
# 0      0   18        1     4     4     0       0           2          2
# 1      0   17        1     1     1     0       0           1          2
# 2      0   15        1     1     1     0       2           1          2
# 3      0   15        1     4     2     1       1           1          3
# 4      0   16        1     3     3     2       1           1          2
# ..   ...  ...      ...   ...   ...   ...     ...         ...        ...
# 390    1   20        1     2     2     3       0           1          2
# 391    1   17        1     3     1     3       0           2          1
# 392    1   21        0     1     1     2       0           1          1
# 393    1   18        0     3     2     3       0           3          1
# 394    1   19        1     1     1     2       0           1          1
#
#      failures  paid  higher  internet  romantic  goout  G1  G2
# 0           0     0       1         0         0      4   5   6
# 1           0     0       1         1         0      3   5   5
# 2           3     1       1         1         0      2   7   8
# 3           0     1       1         1         1      2  15  14
# 4           0     1       1         0         0      2   6  10
# ..        ...   ...     ...       ...       ...    ...  ..  ..
# 390         2     1       1         0         0      4   9   9
# 391         0     0       1         1         0      5  14  16
# 392         3     0       1         0         0      3  10   8
# 393         0     0       1         1         0      1  11  12
# 394         0     0       1         1         0      3   8   9
#
# [395 rows x 17 columns]

# %%
y
# Out:
# 0       6
# 1       6
# 2      10
# 3      15
# 4      10
#        ..
# 390     9
# 391    16
# 392     7
# 393    10
# 394     9
# Name: G3, Length: 395, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(y, kde=True, color='red')
plt.title('grade distribution')
plt.xlabel('G3')
plt.ylabel('frequency')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'frequency')

# %%
plt.hist(data, bins=30, edgecolor='k')
plt.title('Histogram')
plt.show()

# %% [markdown]
# ## Scale the data
# Scaling the data gives it each column in `X` a mean of 0 and standard deviation of 1
#
# we'll use Scaler from sklearn

# %% [markdown]
# ### First let's visualize the data
# And let's see if it is a normal (gaussian distribution)

# %%
plt.hist(X, bins=30, edgecolor='k')
plt.title('Histogram')
plt.show()

# %% [markdown]
# We can see that the data is not normal, rather right-skewed. therefore we shouldn't use z-score normalization.

# %%
plt.hist(y, bins=30, edgecolor='k')
plt.title('Histogram')
plt.show()

# %% [markdown]
# ### Rather, let's use Quantile transformation

# %%
print(f" x mean: {X.mean()}, x standard deviation: {X.std()}")
# Out:
#  x mean: sex            0.473418
# age           16.696203
# address        0.777215
# Medu           2.749367
# Fedu           2.521519
# Mjob           2.169620
# reason         1.255696
# traveltime     1.448101
# studytime      2.035443
# failures       0.334177
# paid           0.458228
# higher         0.949367
# internet       0.832911
# romantic       0.334177
# goout          3.108861
# G1            10.908861
# G2            10.713924
# dtype: float64, x standard deviation: sex           0.499926
# age           1.276043
# address       0.416643
# Medu          1.094735
# Fedu          1.088201
# Mjob          1.227473
# reason        1.208236
# traveltime    0.697505
# studytime     0.839240
# failures      0.743651
# paid          0.498884
# higher        0.219525
# internet      0.373528
# romantic      0.472300
# goout         1.113278
# G1            3.319195
# G2            3.761505
# dtype: float64

# %%
print(f" y mean: {y.mean()}, y standard deviation: {y.std()}")
# Out:
#  y mean: 10.415189873417722, y standard deviation: 4.5814426109978434

# %%
X.shape
# Out:
# (395, 17)

# %%
y.shape
# Out:
# (395,)

# %%
scaler = preprocessing.StandardScaler()
X = scaler.fit_transform(X)

X = (X - X.mean()) / X.std()
y = (y - y.mean()) / y.std()

# %%
X.shape
# Out:
# (395, 17)

# %%
y.shape
# Out:
# (395,)

# %% [markdown]
# ## **Split Data into training and testing, with 80%**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=41, shuffle=True)

# %%
X_train.shape
type(X_train)

# X_train_arr = X_train.values
# type(X_train_arr)
# Out:
# numpy.ndarray

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## **Training PyTorch Model**
#
# Our data has 17 columns, so our model's first layer would have 17 input nodes.
#
# Let's have 2 hidden layers with 34 nodes, 1 more hidden layer with 8 nodes, and 1 output layer.

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.layer1 = nn.Linear(17, 17)
        # 17 inputs and 17 outputs
        self.layer2 = nn.Linear(17, 34)
        #  17 inputs and 8 outputs
        self.layer3 = nn.Linear(34, 17)
        self.layer4 = nn.Linear(17, 8)
        self.output = nn.Linear(8, 1)
        
    # define feed-forward function
    # it takes a feature vector
    def forward(self, x):
        # we use F from the functional package
        # we use it to pass relu function to the layers
        # now hidden layers have RELU activation function
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.relu(self.layer3(x))
        x = F.relu(self.layer4(x))
#         x = self.dropout(x)
        x = self.output(x)
        return x

# %% [markdown]
# ### Tweaking a little bit:
#
# - initialize custom weights
# - gradient clipping

# %%
def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.01)

neuralNet.apply(init_weights)
# Out:
# NeuralNetwork(
#   (layer1): Linear(in_features=17, out_features=17, bias=True)
#   (layer2): Linear(in_features=17, out_features=34, bias=True)
#   (layer3): Linear(in_features=34, out_features=17, bias=True)
#   (layer4): Linear(in_features=17, out_features=8, bias=True)
#   (output): Linear(in_features=8, out_features=1, bias=True)
# )

# %%
#torch.nn.utils.clip_grad_norm_(neuralNet.parameters(), max_norm=1.0)

# %% [markdown]
# ## Let's visualize our model:
# let's see the parameter sizes of each layer

# %%
neuralNet = NeuralNetwork()

param_list = list(neuralNet.parameters())

for i in range(len(param_list)):
    print(param_list[i].shape)
# Out:
# torch.Size([17, 17])
# torch.Size([17])
# torch.Size([34, 17])
# torch.Size([34])
# torch.Size([17, 34])
# torch.Size([17])
# torch.Size([8, 17])
# torch.Size([8])
# torch.Size([1, 8])
# torch.Size([1])

# %% [markdown]
# ## **Convert the X and y datas into Tensors**

# %%
# X_train_array = X_train.values
# X_test_array = X_test.values

# Convert NumPy array to PyTorch tensor
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)

# Convert y_train and y_test to NumPy arrays and then to PyTorch tensors
y_train_array = np.array(y_train)
y_test_array = np.array(y_test)

y_train_tensor = torch.tensor(y_train_array, dtype=torch.float32).reshape(-1, 1)
y_test_tensor = torch.tensor(y_test_array, dtype=torch.float32).reshape(-1, 1)

# %%
X_train_tensor
# Out:
# tensor([[ 1.0547, -0.5463,  0.5354,  ..., -0.0979, -1.1791, -0.1900],
#         [-0.9482,  0.2384,  0.5354,  ..., -0.0979,  0.9325,  0.8747],
#         [-0.9482, -1.3310,  0.5354,  ..., -0.0979,  1.5358,  1.1409],
#         ...,
#         [ 1.0547, -0.5463,  0.5354,  ..., -0.9973,  0.6308,  0.3423],
#         [-0.9482,  0.2384,  0.5354,  ..., -0.9973,  0.0275, -0.4562],
#         [ 1.0547, -1.3310,  0.5354,  ..., -0.9973, -0.2742,  0.3423]])

# %%
y_train_tensor
# Out:
# tensor([[-0.0906],
#         [ 0.7825],
#         [ 1.0007],
#         [-0.7454],
#         [-0.5272],
#         [ 1.0007],
#         [-0.9637],
#         [-0.9637],
#         [-0.3089],
#         [-0.3089],
#         [ 1.2190],
#         [ 1.6556],
#         [-2.2733],
#         [ 1.4373],
#         [ 0.3459],
#         [-2.2733],
#         [ 0.1276],
#         [-1.1820],
#         [-1.1820],
#         [-0.5272],
#         [ 0.7825],
#         [ 1.0007],
#         [-0.3089],
#         [-0.0906],
#         [ 1.0007],
#         [ 1.0007],
#         [-0.9637],
#         [ 0.1276],
#         [ 0.5642],
#         [-2.2733],
#         [-0.0906],
#         [-0.5272],
#         [-0.5272],
#         [ 0.1276],
#         [-0.5272],
#         [-2.2733],
#         [ 0.5642],
#         [ 1.0007],
#         [ 0.3459],
#         [ 0.3459],
#         [ 1.0007],
#         [ 1.6556],
#         [-0.0906],
#         [-0.5272],
#         [-0.3089],
#         [ 0.5642],
#         [ 0.7825],
#         [ 0.7825],
#         [-0.0906],
#         [-0.0906],
#         [-2.2733],
#         [-0.0906],
#         [ 0.7825],
#         [-2.2733],
#         [-0.5272],
#         [ 1.2190],
#         [-0.5272],
#         [ 0.7825],
#         [-0.9637],
#         [ 1.4373],
#         [-0.0906],
#         [ 0.5642],
#         [-0.5272],
#         [ 0.3459],
#         [ 0.5642],
#         [ 1.0007],
#         [ 0.1276],
#         [ 1.6556],
#         [-0.5272],
#         [ 0.7825],
#         [-0.5272],
#         [ 1.8738],
#         [-0.0906],
#         [ 0.7825],
#         [-0.0906],
#         [-0.0906],
#         [ 1.6556],
#         [-0.3089],
#         [ 0.5642],
#         [ 0.1276],
#         [ 0.1276],
#         [-0.0906],
#         [ 0.5642],
#         [ 0.5642],
#         [-0.0906],
#         [ 0.5642],
#         [-2.2733],
#         [ 0.1276],
#         [ 0.1276],
#         [-0.0906],
#         [-2.2733],
#         [-0.3089],
#         [-0.9637],
#         [ 1.0007],
#         [ 0.1276],
#         [ 0.1276],
#         [-0.3089],
#         [ 0.7825],
#         [-1.1820],
#         [ 0.1276],
#         [ 0.3459],
#         [ 0.1276],
#         [-0.0906],
#         [-2.2733],
#         [ 0.7825],
#         [-0.5272],
#         [ 1.0007],
#         [-0.3089],
#         [ 1.6556],
#         [-0.7454],
#         [ 1.2190],
#         [ 0.5642],
#         [ 1.8738],
#         [-0.0906],
#         [-2.2733],
#         [ 1.6556],
#         [-0.7454],
#         [-0.0906],
#         [-2.2733],
#         [-2.2733],
#         [ 0.3459],
#         [-0.0906],
#         [-0.0906],
#         [ 0.3459],
#         [-0.3089],
#         [-0.5272],
#         [ 0.5642],
#         [-0.0906],
#         [-0.0906],
#         [-0.5272],
#         [-2.2733],
#         [-0.5272],
#         [ 0.1276],
#         [-0.3089],
#         [ 1.0007],
#         [-2.2733],
#         [ 0.1276],
#         [-1.1820],
#         [-0.5272],
#         [ 0.5642],
#         [-0.5272],
#         [-0.7454],
#         [-0.5272],
#         [-0.0906],
#         [ 1.0007],
#         [-0.3089],
#         [-0.0906],
#         [ 1.2190],
#         [-2.2733],
#         [ 1.2190],
#         [ 1.2190],
#         [-0.0906],
#         [-0.0906],
#         [ 0.3459],
#         [ 0.5642],
#         [ 0.1276],
#         [-0.9637],
#         [ 0.3459],
#         [ 0.5642],
#         [-0.5272],
#         [ 0.7825],
#         [ 0.1276],
#         [-0.7454],
#         [ 1.0007],
#         [-2.2733],
#         [-2.2733],
#         [ 1.2190],
#         [-0.0906],
#         [ 1.4373],
#         [-0.5272],
#         [-0.0906],
#         [ 1.4373],
#         [ 0.3459],
#         [ 1.6556],
#         [-0.0906],
#         [ 0.1276],
#         [-0.0906],
#         [ 1.0007],
#         [-2.2733],
#         [ 0.3459],
#         [ 0.3459],
#         [ 1.0007],
#         [ 0.1276],
#         [ 0.1276],
#         [ 0.1276],
#         [ 0.1276],
#         [-2.2733],
#         [-0.5272],
#         [ 0.3459],
#         [ 0.5642],
#         [ 0.3459],
#         [-2.2733],
#         [-0.3089],
#         [ 0.7825],
#         [ 0.1276],
#         [ 0.3459],
#         [ 0.1276],
#         [ 0.5642],
#         [ 0.3459],
#         [-0.5272],
#         [-0.7454],
#         [ 1.2190],
#         [ 0.7825],
#         [ 0.7825],
#         [ 0.3459],
#         [ 0.5642],
#         [ 0.3459],
#         [-0.7454],
#         [-2.2733],
#         [ 1.0007],
#         [ 1.2190],
#         [-0.0906],
#         [-0.3089],
#         [-0.5272],
#         [ 1.2190],
#         [ 0.1276],
#         [-1.1820],
#         [-2.2733],
#         [ 1.0007],
#         [-0.0906],
#         [-1.1820],
#         [-0.0906],
#         [ 1.0007],
#         [ 1.0007],
#         [-0.3089],
#         [-2.2733],
#         [-0.3089],
#         [-0.9637],
#         [-0.3089],
#         [-0.0906],
#         [-0.5272],
#         [-2.2733],
#         [ 1.8738],
#         [-0.0906],
#         [ 0.5642],
#         [-0.0906],
#         [-0.5272],
#         [-1.1820],
#         [ 0.1276],
#         [-0.9637],
#         [ 0.7825],
#         [ 0.7825],
#         [ 0.1276],
#         [ 0.3459],
#         [-0.3089],
#         [ 1.2190],
#         [-0.3089],
#         [ 2.0921],
#         [ 1.8738],
#         [-0.5272],
#         [-0.3089],
#         [ 0.1276],
#         [ 0.1276],
#         [-0.0906],
#         [ 0.5642],
#         [-0.0906],
#         [-0.0906],
#         [ 0.7825],
#         [-2.2733],
#         [ 1.0007],
#         [ 0.7825],
#         [-0.0906],
#         [-0.0906],
#         [ 0.7825],
#         [ 1.0007],
#         [ 0.5642],
#         [ 0.7825],
#         [ 0.1276],
#         [ 1.0007],
#         [-0.3089],
#         [-2.2733],
#         [ 1.4373],
#         [ 0.7825],
#         [-0.0906],
#         [ 1.2190],
#         [-0.0906],
#         [ 0.3459],
#         [ 1.0007],
#         [-2.2733],
#         [ 0.3459],
#         [-0.9637],
#         [-0.3089],
#         [ 0.7825],
#         [-0.0906],
#         [ 1.6556],
#         [ 0.1276],
#         [ 1.6556],
#         [-2.2733],
#         [-0.0906],
#         [-0.3089],
#         [-0.0906],
#         [-0.0906],
#         [ 0.1276],
#         [ 1.0007],
#         [ 0.5642],
#         [ 1.6556],
#         [ 0.1276],
#         [-0.5272],
#         [-0.9637],
#         [-0.9637],
#         [-0.0906],
#         [ 0.1276],
#         [ 0.1276],
#         [ 1.0007],
#         [-0.0906],
#         [ 1.6556],
#         [-0.3089],
#         [-0.0906],
#         [-2.2733],
#         [ 0.5642],
#         [-0.0906],
#         [ 0.3459],
#         [-0.7454],
#         [ 0.3459],
#         [-0.3089],
#         [ 0.3459]])

# %%
X_test_tensor
# Out:
# tensor([[-0.9482,  1.0230, -1.8678,  ..., -0.9973,  0.9325,  0.3423],
#         [-0.9482, -0.5463,  0.5354,  ..., -0.9973,  0.3292,  0.6085],
#         [-0.9482, -0.5463,  0.5354,  ..., -0.9973, -1.4808, -0.4562],
#         ...,
#         [ 1.0547, -1.3310,  0.5354,  ..., -0.9973,  0.3292,  0.3423],
#         [-0.9482, -1.3310,  0.5354,  ..., -0.9973,  1.2341,  0.8747],
#         [-0.9482, -0.5463,  0.5354,  ..., -0.9973, -2.0841, -2.8519]])

# %%
y_test_tensor
# Out:
# tensor([[ 0.1276],
#         [ 0.3459],
#         [-0.5272],
#         [ 0.5642],
#         [-2.2733],
#         [-0.5272],
#         [ 0.3459],
#         [ 0.1276],
#         [-0.0906],
#         [-2.2733],
#         [ 1.2190],
#         [-0.3089],
#         [ 1.0007],
#         [-0.3089],
#         [-1.4003],
#         [ 0.1276],
#         [ 1.0007],
#         [ 0.5642],
#         [ 0.3459],
#         [-0.3089],
#         [ 1.6556],
#         [ 0.7825],
#         [-2.2733],
#         [ 1.0007],
#         [ 0.5642],
#         [ 0.1276],
#         [ 0.5642],
#         [-0.5272],
#         [ 1.4373],
#         [-0.3089],
#         [ 0.1276],
#         [-0.9637],
#         [ 0.5642],
#         [-0.5272],
#         [ 0.7825],
#         [-0.0906],
#         [ 0.5642],
#         [-0.9637],
#         [ 0.7825],
#         [ 0.1276],
#         [-0.0906],
#         [ 1.0007],
#         [-2.2733],
#         [ 0.1276],
#         [ 0.3459],
#         [-0.9637],
#         [ 0.3459],
#         [-2.2733],
#         [ 0.1276],
#         [-0.0906],
#         [-2.2733],
#         [ 1.0007],
#         [ 0.7825],
#         [-2.2733],
#         [ 0.1276],
#         [-0.0906],
#         [ 0.7825],
#         [-0.5272],
#         [ 1.8738],
#         [ 0.5642],
#         [-0.7454],
#         [ 0.1276],
#         [-2.2733],
#         [-0.9637],
#         [ 1.0007],
#         [ 0.3459],
#         [ 1.2190],
#         [ 0.1276],
#         [-0.0906],
#         [ 1.2190],
#         [ 0.1276],
#         [ 1.0007],
#         [ 0.3459],
#         [ 0.5642],
#         [ 0.5642],
#         [ 1.2190],
#         [ 0.1276],
#         [ 1.0007],
#         [-2.2733]])

# %% [markdown]
# ## Gradient Descent (Optimizer) and Loss (criterion)
# We use the `Adam` Optimizer with `MSE` loss function and `0.1` learning rate

# %%
optimizer = torch.optim.Adam(neuralNet.parameters(), lr=0.001, weight_decay=1e-5)
criterion = nn.MSELoss()

# %% [markdown]
# ## Training the model within 100 epochs

# %% [markdown]
# ### **First let's define code for training one epoch**

# %%
batch_size = 32  # Example batch size, adjust as needed

# Create a DataLoader instance with the specified batch size
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

#X_test_tensor.shape
y_test_tensor.shape
# Out:
# torch.Size([79, 1])

# %% [markdown]
# ### **Train Loop**

# %%
def train_loop(dataloader, model, loss_function, optimizer):
    size = len(dataloader.dataset)
    
    model.train()
    
    for batch, (X, y) in enumerate(dataloader):
        # compute prediction and loss
        pred = model(X)
        loss = loss_function(pred, y)
        
        # backpropagation
        optimizer.zero_grad()
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        # make the gradient zero to prevent buildup
        
        
        if batch % 100 == 0:
            loss, current = loss.item(), batch * batch_size + len(X)
            print(f"loss: {loss:>7f} [{current:>5d}/{size:5d}]")

# %% [markdown]
# ## **Test Loop**

# %%
losses = []
accuracies = []
def test_loop(dataloader, model, loss_function):
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct, total_predictions = 0, 0, 0
    
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            # Calculate MSE loss
            mse_loss = ((pred - y)**2).mean().item()
            #print(f"pred: {pred}")
            #print(f"pred: {y}")
            
            # Count the number of matching values within the batch
            num_matches = torch.sum(torch.round(pred) == torch.round(y)).item()

            print(f"Number of matching values in this batch: {num_matches} out of {len(y)}")
            test_loss += mse_loss

            # Accumulate the number of correct predictions and total predictions
            correct += num_matches
            total_predictions += len(y)

    # Calculate average MSE loss
    test_loss /= len(dataloader.dataset)
    
    losses.append(test_loss)
    # Calculate accuracy percentage
    accuracy_percentage = (correct / total_predictions) * 100
    accuracies.append(accuracy_percentage)
    print(f"Test Error: \n Accuracy: {accuracy_percentage:>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return pred

# %% [markdown]
# ## now train all epochs

# %%
num_epochs = 100
predictions = []
best_loss = np.inf
patience = 10
counter = 0


for t in range(num_epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, neuralNet, criterion, optimizer)
    prediction = test_loop(test_dataloader, neuralNet, criterion)
    predictions.append(prediction)
    
    # Check if the test loss has improved
    if losses[-1] < best_loss:
        best_loss = losses[-1]
        counter = 0
    else:
        counter += 1
    
    # If test loss hasn't improved for 'patience' epochs, stop training
    if counter >= patience:
        print("Early stopping!")
        break
# Out:
# Epoch 1
# -------------------------------
# loss: 0.794534 [   32/  316]
# Number of matching values in this batch: 14 out of 32
# Number of matching values in this batch: 11 out of 32
# Number of matching values in this batch: 5 out of 15
# Test Error:
#  Accuracy: 38.0%, Avg loss: 0.039791
#
# Epoch 2
# -------------------------------
# loss: 0.938058 [   32/  316]
# Number of matching values in this batch: 13 out of 32
# Number of matching values in this batch: 13 out of 32
# Number of matching values in this batch: 4 out of 15
# Test Error:
#  Accuracy: 38.0%, Avg loss: 0.041025
#
# Epoch 3
# -------------------------------
# loss: 1.370438 [   32/  316]
# Number of matching values in this batch: 13 out of 32
# Number of matching values in this batch: 13 out of 32
# Number of matching values in this batch: 4 out of 15
# Test Error:
#  Accuracy: 38.0%, Avg loss: 0.041127
#
# Epoch 4
# -------------------------------
# loss: 1.299091 [   32/  316]
# Number of matching values in this batch: 9 out of 32
# Number of matching values in this batch: 14 out of 32
# Number of matching values in this batch: 7 out of 15
# Test Error:
#  Accuracy: 38.0%, Avg loss: 0.037392
#
# Epoch 5
# -------------------------------
# loss: 0.484462 [   32/  316]
# Number of matching values in this batch: 11 out of 32
# Number of matching values in this batch: 13 out of 32
# Number of matching values in this batch: 5 out of 15
# Test Error:
#  Accuracy: 36.7%, Avg loss: 0.036677
#
# Epoch 6
# -------------------------------
# loss: 0.332530 [   32/  316]
# Number of matching values in this batch: 12 out of 32
# Number of matching values in this batch: 7 out of 32
# Number of matching values in this batch: 8 out of 15
# Test Error:
#  Accuracy: 34.2%, Avg loss: 0.032525
#
# Epoch 7
# -------------------------------
# loss: 0.795974 [   32/  316]
# Number of matching values in this batch: 11 out of 32
# Number of matching values in this batch: 13 out of 32
# Number of matching values in this batch: 3 out of 15
# Test Error:
#  Accuracy: 34.2%, Avg loss: 0.033173
#
# Epoch 8
# -------------------------------
# loss: 0.528890 [   32/  316]
# Number of matching values in this batch: 9 out of 32
# Number of matching values in this batch: 16 out of 32
# Number of matching values in this batch: 5 out of 15
# Test Error:
#  Accuracy: 38.0%, Avg loss: 0.025165
#
# Epoch 9
# -------------------------------
# loss: 0.491565 [   32/  316]
# Number of matching values in this batch: 15 out of 32
# Number of matching values in this batch: 17 out of 32
# Number of matching values in this batch: 9 out of 15
# Test Error:
#  Accuracy: 51.9%, Avg loss: 0.023865
#
# Epoch 10
# -------------------------------
# loss: 0.406440 [   32/  316]
# Number of matching values in this batch: 17 out of 32
# Number of matching values in this batch: 22 out of 32
# Number of matching values in this batch: 8 out of 15
# Test Error:
#  Accuracy: 59.5%, Avg loss: 0.017650
#
# Epoch 11
# -------------------------------
# loss: 0.165710 [   32/  316]
# Number of matching values in this batch: 22 out of 32
# Number of matching values in this batch: 23 out of 32
# Number of matching values in this batch: 10 out of 15
# Test Error:
#  Accuracy: 69.6%, Avg loss: 0.014346
#
# Epoch 12
# -------------------------------
# loss: 0.316630 [   32/  316]
# Number of matching values in this batch: 23 out of 32
# Number of matching values in this batch: 20 out of 32
# Number of matching values in this batch: 12 out of 15
# Test Error:
#  Accuracy: 69.6%, Avg loss: 0.010310
#
# Epoch 13
# -------------------------------
# loss: 0.382344 [   32/  316]
# Number of matching values in this batch: 21 out of 32
# Number of matching values in this batch: 26 out of 32
# Number of matching values in this batch: 10 out of 15
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.010575
#
# Epoch 14
# -------------------------------
# loss: 0.110243 [   32/  316]
# Number of matching values in this batch: 26 out of 32
# Number of matching values in this batch: 25 out of 32
# Number of matching values in this batch: 9 out of 15
# Test Error:
#  Accuracy: 75.9%, Avg loss: 0.009905
#
# Epoch 15
# -------------------------------
# loss: 0.125868 [   32/  316]
# Number of matching values in this batch: 26 out of 32
# Number of matching values in this batch: 29 out of 32
# Number of matching values in this batch: 6 out of 15
# Test Error:
#  Accuracy: 77.2%, Avg loss: 0.012549
#
# Epoch 16
# -------------------------------
# loss: 0.185190 [   32/  316]
# Number of matching values in this batch: 27 out of 32
# Number of matching values in this batch: 23 out of 32
# Number of matching values in this batch: 11 out of 15
# Test Error:
#  Accuracy: 77.2%, Avg loss: 0.009474
#
# Epoch 17
# -------------------------------
# loss: 0.168837 [   32/  316]
# Number of matching values in this batch: 24 out of 32
# Number of matching values in this batch: 26 out of 32
# Number of matching values in this batch: 10 out of 15
# Test Error:
#  Accuracy: 75.9%, Avg loss: 0.010516
#
# Epoch 18
# -------------------------------
# loss: 0.054212 [   32/  316]
# Number of matching values in this batch: 28 out of 32
# Number of matching values in this batch: 23 out of 32
# Number of matching values in this batch: 11 out of 15
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.010927
#
# Epoch 19
# -------------------------------
# loss: 0.063217 [   32/  316]
# Number of matching values in this batch: 23 out of 32
# Number of matching values in this batch: 25 out of 32
# Number of matching values in this batch: 12 out of 15
# Test Error:
#  Accuracy: 75.9%, Avg loss: 0.008771
#
# Epoch 20
# -------------------------------
# loss: 0.128743 [   32/  316]
# Number of matching values in this batch: 22 out of 32
# Number of matching values in this batch: 24 out of 32
# Number of matching values in this batch: 13 out of 15
# Test Error:
#  Accuracy: 74.7%, Avg loss: 0.008408
#
# Epoch 21
# -------------------------------
# loss: 0.112172 [   32/  316]
# Number of matching values in this batch: 22 out of 32
# Number of matching values in this batch: 28 out of 32
# Number of matching values in this batch: 12 out of 15
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.008734
#
# Epoch 22
# -------------------------------
# loss: 0.076672 [   32/  316]
# Number of matching values in this batch: 24 out of 32
# Number of matching values in this batch: 22 out of 32
# Number of matching values in this batch: 13 out of 15
# Test Error:
#  Accuracy: 74.7%, Avg loss: 0.007550
#
# Epoch 23
# -------------------------------
# loss: 0.172924 [   32/  316]
# Number of matching values in this batch: 25 out of 32
# Number of matching values in this batch: 27 out of 32
# Number of matching values in this batch: 9 out of 15
# Test Error:
#  Accuracy: 77.2%, Avg loss: 0.009619
#
# Epoch 24
# -------------------------------
# loss: 0.117880 [   32/  316]
# Number of matching values in this batch: 25 out of 32
# Number of matching values in this batch: 28 out of 32
# Number of matching values in this batch: 8 out of 15
# Test Error:
#  Accuracy: 77.2%, Avg loss: 0.010480
#
# Epoch 25
# -------------------------------
# loss: 0.229544 [   32/  316]
# Number of matching values in this batch: 25 out of 32
# Number of matching values in this batch: 23 out of 32
# Number of matching values in this batch: 10 out of 15
# Test Error:
#  Accuracy: 73.4%, Avg loss: 0.008022
#
# Epoch 26
# -------------------------------
# loss: 0.185532 [   32/  316]
# Number of matching values in this batch: 24 out of 32
# Number of matching values in this batch: 25 out of 32
# Number of matching values in this batch: 13 out of 15
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.008030
#
# Epoch 27
# -------------------------------
# loss: 0.067305 [   32/  316]
# Number of matching values in this batch: 25 out of 32
# Number of matching values in this batch: 21 out of 32
# Number of matching values in this batch: 13 out of 15
# Test Error:
#  Accuracy: 74.7%, Avg loss: 0.008950
#
# Epoch 28
# -------------------------------
# loss: 0.062691 [   32/  316]
# Number of matching values in this batch: 24 out of 32
# Number of matching values in this batch: 24 out of 32
# Number of matching values in this batch: 12 out of 15
# Test Error:
#  Accuracy: 75.9%, Avg loss: 0.008615
#
# Epoch 29
# -------------------------------
# loss: 0.104877 [   32/  316]
# Number of matching values in this batch: 24 out of 32
# Number of matching values in this batch: 24 out of 32
# Number of matching values in this batch: 12 out of 15
# Test Error:
#  Accuracy: 75.9%, Avg loss: 0.009650
#
# Epoch 30
# -------------------------------
# loss: 0.099835 [   32/  316]
# Number of matching values in this batch: 22 out of 32
# Number of matching values in this batch: 24 out of 32
# Number of matching values in this batch: 12 out of 15
# Test Error:
#  Accuracy: 73.4%, Avg loss: 0.007765
#
# Epoch 31
# -------------------------------
# loss: 0.218017 [   32/  316]
# Number of matching values in this batch: 23 out of 32
# Number of matching values in this batch: 26 out of 32
# Number of matching values in this batch: 11 out of 15
# Test Error:
#  Accuracy: 75.9%, Avg loss: 0.010725
#
# Epoch 32
# -------------------------------
# loss: 0.172511 [   32/  316]
# Number of matching values in this batch: 23 out of 32
# Number of matching values in this batch: 24 out of 32
# Number of matching values in this batch: 13 out of 15
# Test Error:
#  Accuracy: 75.9%, Avg loss: 0.009327
#
# Early stopping!

# %%
plt.figure(figsize=(12, 6))

# Plot Losses
plt.subplot(1, 2, 1)
plt.plot(losses, label='Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Training Loss over Time')
plt.legend()

# Plot Accuracies
plt.subplot(1, 2, 2)
plt.plot(accuracies, label='Accuracy', color='orange')
plt.xlabel('Iteration')
plt.ylabel('Accuracy (%)')
plt.title('Training Accuracy over Time')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### New data

# %%
### unseen data

# Mean and standard deviation for each feature
x_mean = np.array([0.473418, 16.696203, 0.777215, 2.749367, 2.521519, 2.169620, 1.255696, 1.448101, 2.035443, 0.334177, 0.458228, 0.949367, 0.832911, 0.334177, 3.108861, 10.908861, 10.713924])
x_std = np.array([0.499926, 1.276043, 0.416643, 1.094735, 1.088201, 1.227473, 1.208236, 0.697505, 0.839240, 0.743651, 0.498884, 0.219525, 0.373528, 0.472300, 1.113278, 3.319195, 3.761505])

# Number of features
num_features = len(x_mean)

# Generate random values for each feature based on normal distribution with given mean and standard deviation
unseen_data = {}
for i in range(num_features):
    feature_name = f'Feature_{i+1}'
    mean = x_mean[i]
    std = x_std[i]
    value = np.random.normal(mean, std)
    unseen_data[feature_name] = [value]

# Convert dictionary to DataFrame
unseen_df = pd.DataFrame(unseen_data)

# Display the generated unseen data
print("Unseen Data:")
print(unseen_df)
# Out:
# Unseen Data:
#    Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0   0.182011    16.4343   1.006398   3.267522   3.771455    3.60432
#
#    Feature_7  Feature_8  Feature_9  Feature_10  Feature_11  Feature_12  \
# 0   2.458406   0.949825   3.206408    0.571668    0.227809    1.288145
#
#    Feature_13  Feature_14  Feature_15  Feature_16  Feature_17
# 0    1.142488    0.190362    2.499592   14.133768    11.44524

# %%
# Scale the unseen data using the same mean and standard deviation values as the training data
unseen_scaled = (unseen_df.values - x_mean) / x_std

# Convert the scaled unseen data to a PyTorch tensor
unseen_tensor = torch.tensor(unseen_scaled, dtype=torch.float32)

# Make predictions using your trained model
with torch.no_grad():
    neuralNet.eval()  # Set the model to evaluation mode
    predictions = neuralNet(unseen_tensor)

# Convert predictions tensor to numpy array
predictions_array = predictions.numpy()

# Display the predictions
print("Predictions:")
print(predictions_array)

# Convert the predictions back to original scale
predictions_unscaled = predictions_array * y.std() + y.mean()

# Plot the actual training and test data along with the predictions
plt.figure(figsize=(10, 6))

# Plot training data
plt.scatter(range(len(y_train)), y_train, color='blue', label='Training Data')

# Plot test data
plt.scatter(range(len(y_train), len(y_train) + len(y_test)), y_test, color='red', label='Test Data')

# Plot unseen data predictions
plt.scatter(len(y_train) + len(y_test), predictions_unscaled, color='green', label='Unseen Data Predictions')

plt.xlabel('Sample Index')
plt.ylabel('Target Value')
plt.title('Comparison of Predictions on Unseen Data with Training and Test Data')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Predictions:
# [[0.6478266]]

# %% [markdown]
# ## **Save the model**

# %%
torch.save(neuralNet.state_dict(), 'model.pth')

# %% [markdown]
# ## **Load model**:

# %%
model = NeuralNetwork()  # Instantiate your model
model.load_state_dict(torch.load('model.pth'))
model.eval()  # Set the model to evaluation mode if needed
# Out:
# NeuralNetwork(
#   (layer1): Linear(in_features=17, out_features=17, bias=True)
#   (layer2): Linear(in_features=17, out_features=34, bias=True)
#   (layer3): Linear(in_features=34, out_features=17, bias=True)
#   (layer4): Linear(in_features=17, out_features=8, bias=True)
#   (output): Linear(in_features=8, out_features=1, bias=True)
# )

# %% [markdown]
# ### New data (from user prompt)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# Define the columns of the dataset
columns = ['sex', 'age', 'address', 'Medu', 'Fedu', 'Mjob', 'reason', 'traveltime', 
           'studytime', 'failures', 'paid', 'higher', 'internet', 'romantic', 
           'goout', 'G1', 'G2', 'G3']

# Define the mean and standard deviation of the original data
original_mean = pd.Series({
    'sex': 0.473418,
    'age': 16.696203,
    'address': 0.777215,
    'Medu': 2.749367,
    'Fedu': 2.521519,
    'Mjob': 2.169620,
    'reason': 1.255696,
    'traveltime': 1.448101,
    'studytime': 2.035443,
    'failures': 0.334177,
    'paid': 0.458228,
    'higher': 0.949367,
    'internet': 0.832911,
    'romantic': 0.334177,
    'goout': 3.108861,
    'G1': 10.908861,
    'G2': 10.713924
})

original_std = pd.Series({
    'sex': 0.499926,
    'age': 1.276043,
    'address': 0.416643,
    'Medu': 1.094735,
    'Fedu': 1.088201,
    'Mjob': 1.227473,
    'reason': 1.208236,
    'traveltime': 0.697505,
    'studytime': 0.839240,
    'failures': 0.743651,
    'paid': 0.498884,
    'higher': 0.219525,
    'internet': 0.373528,
    'romantic': 0.472300,
    'goout': 1.113278,
    'G1': 3.319195,
    'G2': 3.761505
})

# Load the label encoded data
# data = pd.read_csv('your_label_encoded_data.csv')  # Replace with your file path

# Define a function to reverse the label encoding
def reverse_label_encoding(label, column):
    le = LabelEncoder()
    le.fit(data[column])
    return le.inverse_transform([label])[0]

# Prompt the user to enter new data
new_data = {}
for column in columns:
    if column in ['school', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup', 
                  'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']:
        label = input(f"Enter the label for {column}: ")
        new_data[column] = reverse_label_encoding(int(label), column)
    else:
        value = float(input(f"Enter the value for {column} (standardized): "))
        new_data[column] = value

# Convert the new data to a DataFrame
new_data_df = pd.DataFrame([new_data])

# Reverse the standardization
for column in columns:
    new_data_df[column] = (new_data_df[column] * original_std[column]) + original_mean[column]

# Print the new data
print("\nNew data:")
print(new_data_df)

# Now you can use the new data to make predictions using your model
# Out:
# Enter the value for sex (standardized):  0
# Enter the value for age (standardized):  18
# Enter the value for address (standardized):  134
# Enter the value for Medu (standardized):  343
# Enter the value for Fedu (standardized):  343
# Enter the label for Mjob:  343
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1424], line 66
#      63 if column in ['school', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup',
#      64               'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']:
#      65     label = input(f"Enter the label for {column}: ")
# ---> 66     new_data[column] = reverse_label_encoding(int(label), column)
#      67 else:
#      68     value = float(input(f"Enter the value for {column} (standardized): "))
#
# Cell In[1424], line 58, in reverse_label_encoding(label, column)
#      56 le = LabelEncoder()
#      57 le.fit(data[column])
# ---> 58 return le.inverse_transform([label])[0]
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:162, in LabelEncoder.inverse_transform(self, y)
#     160 diff = np.setdiff1d(y, np.arange(len(self.classes_)))
#     161 if len(diff):
# --> 162     raise ValueError("y contains previously unseen labels: %s" % str(diff))
#     163 y = np.asarray(y)
#     164 return self.classes_[y]
#
# ValueError: y contains previously unseen labels: [343]
